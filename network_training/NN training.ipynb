# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import sklearn.model_selection as sk
from random import randint
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle


import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from tensorflow.keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
#READ DATA FROM CSV + PADDING/TRUNCATING TO 15

import numpy as np

def read_csv(filename):
    file = open(filename)

    lines = file.readline() # Consumes CSV header
    lines = file.readline()
    lines_list = lines.split(",")
    batch = lines_list[0]
    
    raw_inputs = [[], [], []] # For acceleromter readings xyz wrist and xyz arm

    label_list = []
    label = 0
    
    total_inputs = []

    try:
        while lines:
            lines_list = lines.split(",")
            
#             if int(batch) > 10:
#                 break;

            if batch != lines_list[0]:
                previous_batch = batch
                batch = lines_list[0]
                
#                 padded_inputs = tf.keras.preprocessing.sequence.pad_sequences(
#                     raw_inputs, padding="post", maxlen=100, truncating='post'
#                 )
                total_inputs.append(raw_inputs)
                label_list.append(int(label))
                label = 0


                raw_inputs = [[], [], []] # For acceleromter readings xyz wrist and xyz arm
                raw_inputs[0].append(np.int8(lines_list[5]))
                raw_inputs[1].append(np.int8(lines_list[6]))
                raw_inputs[2].append(np.int8(lines_list[7]))
                print(np.int8(lines_list[7]), lines_list[7])

                
            else:
                label = lines_list[21]
                raw_inputs[0].append(np.int8(lines_list[5]))
                raw_inputs[1].append(np.int8(lines_list[6]))
                raw_inputs[2].append(np.int8(lines_list[7]))

              
                
            lines = file.readline()
    except IndexError:
        print(batch)
        
    return total_inputs, label_list

# %%
# a, lable_list = read_csv('new_combine.csv')
# a, lable_list = read_csv('all_combined.csv')

a, lable_list = read_csv('j_grenade.csv')
# combined_samples_one_column = combined_samples.reshape([-1,1])
# Out:
# 16 16
# -2 -2
# -35 -35
# -7 -7
# 11 11
# 27 27
# -14 -14
# 2 2
# 23 23
# -1 -1
# 17 17
# 40 40
# -30 -30
# -35 -35
# -63 -63
# 60 60
# -2 -2
# 42 42
# -7 -7
# -4 -4
# -9 -9
# -12 -12
# 4 4
# 27 27
# 35 35
# -2 -2
# 3 3
# -1 -1
# -16 -16
# -15 -15
# -2 -2
# 2 2
# 6 6
# 19 19
# -11 -11
# -21 -21
# -30 -30
# -23 -23
# -22 -22
# -33 -33
# -14 -14
# 0 0
# -16 -16
# -31 -31
# 8 8
# 22 22
# -19 -19
# 7 7
# 9 9
# 3 3
# 6 6
# 4 4
# 14 14
# 5 5
# 0 0
# 31 31
# 50 50
# 28 28
# -28 -28
# -4 -4
# 1 1
# 9 9
# -39 -39
# 7 7
# -4 -4
# 5 5
# -7 -7
# -2 -2
# -43 -43
# 1 1
# 11 11
# -6 -6
# -15 -15
# -50 -50
# -17 -17
# 12 12
# 12 12
# 10 10
# -3 -3
# -12 -12
# -10 -10
# 6 6
# -2 -2
# -5 -5
# 5 5
# -9 -9
# -19 -19
# -11 -11
# -11 -11
# -18 -18
# -8 -8
# -9 -9
# -8 -8
# -16 -16
# -15 -15
# -13 -13
# 13 13
# -5 -5
# 8 8
# 16 16
# 18 18
# -29 -29
# 11 11
# -2 -2
# 13 13
# -9 -9
# 11 11
# 7 7
# -19 -19
# 9 9
# 24 24
# 0 0
# -1 -1
# 22 22
# 29 29
# 48 48
# 38 38
# 3 3
# 36 36
# 10 10
# 8 8
# -1 -1
# ...

# %%
combined_samples = []
container = []
for i in range(len(a)):
    for j in range(len(a[0])):
        container.extend(a[i][j])
    combined_samples.append(container)
    container = []
    
    
    
combined_samples = np.array(combined_samples)
lable_list = np.array(lable_list)

combined_samples, lable_list = shuffle(combined_samples, lable_list)

scaled_samples = combined_samples

print(combined_samples.shape)
X_train, X_test, y_train, y_test = sk.train_test_split(combined_samples, lable_list, test_size=0.33)


inputs = keras.Input(shape=(300,), dtype=tf.int8)
layer_1 = layers.Dense(64, activation="relu")
layer_1_output = layer_1(inputs) 

layer_2 = layers.Dense(64, activation="relu")
layer_2_output = layer_2(layer_1_output) 

# layer_3 = layers.Dense(64, activation="relu")
# layer_3_output = layer_3(layer_2_output) 

# layer_4 = layers.Dense(64, activation="relu")
# layer_4_output = layer_4(layer_3_output) 

outputs = layers.Dense(5, activation="softmax")(layer_2_output)

model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")
model.summary()
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=["accuracy"],
)
# Out:
# (2358, 300)
# Model: "mnist_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                19264
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# ...
# Total params: 23,749
# Trainable params: 23,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(len(X_train[0]))
# Out:
# 300

# %%
combined_samples = np.array(combined_samples)
lable_list = np.array(lable_list)

combined_samples, lable_list = shuffle(combined_samples, lable_list)

# scaler = MinMaxScaler(feature_range=(0,1))
# combined_samples_one_column = combined_samples.reshape([-1,1])




# result_one_column = scaler.fit_transform(combined_samples_one_column)
# scaled_samples = result_one_column.reshape(combined_samples.shape)


scaled_samples = combined_samples

print(scaled_samples.shape)

# %%
print(type(combined_samples[0][0]))

# %%
X_train, X_test, y_train, y_test = sk.train_test_split(combined_samples, lable_list, test_size=0.33)

# %%
inputs = keras.Input(shape=(300,), dtype=tf.int8)
layer_1 = layers.Dense(64, activation="relu")
layer_1_output = layer_1(inputs) 

layer_2 = layers.Dense(64, activation="relu")
layer_2_output = layer_2(layer_1_output) 

# layer_3 = layers.Dense(64, activation="relu")
# layer_3_output = layer_3(layer_2_output) 

# layer_4 = layers.Dense(64, activation="relu")
# layer_4_output = layer_4(layer_3_output) 

outputs = layers.Dense(5, activation="softmax")(layer_2_output)

# %%
model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")
model.summary()
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=["accuracy"],
)


# model.compile(
#     loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#     optimizer=keras.optimizers.RMSprop(),
#     metrics=["accuracy"],
# )

# %%
import keras.backend as K

def size(model): # Compute number of params in a model (the actual number of floats)
    return sum([np.prod(K.get_value(w).shape) for w in model.trainable_weights])

print(size(model))

# %%
model.fit(X_train, y_train, validation_split=0.1, batch_size=10, epochs=5, shuffle=True, verbose=2)
# Out:
# Epoch 1/5
# 143/143 - 0s - loss: 1.1132e-06 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 2/5
# 143/143 - 0s - loss: 1.0317e-06 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 3/5
# 143/143 - 0s - loss: 9.5002e-07 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 4/5
# 143/143 - 0s - loss: 8.8487e-07 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 5/5
# 143/143 - 0s - loss: 8.2022e-07 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000

# %%
X_test = scaled_samples
y_test = lable_list
print(type(X_test[0][0]))

# %%
test_scores = model.evaluate(X_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# 25/25 - 0s - loss: 1.0039 - accuracy: 0.9718
# Test loss: 1.0038931369781494
# Test accuracy: 0.9717586636543274

# %%
# q = model.predict(test_data[0][None,...])

model.save('j_grenade.h5')
# from keras.models import load_model

# model = load_model('kw_jl.h5')

# %%
model.summary()
# model.layers[1].get_weights()

for layer in model.layers:
  print(layer.get_config())

for layer in model.layers:
  print(layer.get_weights())
# Out:
# Model: "mnist_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                19264
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# ...
# Total params: 23,749
# Trainable params: 23,749
# Non-trainable params: 0
# _________________________________________________________________
# {'batch_input_shape': (None, 300), 'dtype': 'int8', 'sparse': False, 'ragged': False, 'name': 'input_1'}
# ...

# %%
max_int = 0
min_int = 0

# test_sam = scaled_samples[1278]
# test_label = lable_list[1278]
weights_1 = model.layers[1].get_weights()[0]
biases_1 = model.layers[1].get_weights()[1]


weights_2 = model.layers[2].get_weights()[0]
biases_2  = model.layers[2].get_weights()[1]

weights_3 = model.layers[3].get_weights()[0]
biases_3  = model.layers[3].get_weights()[1]

# results = []
# results_2 = []
# results_3 = []

# number_nodes = 64
# number_inputs = 300
# output_nodes = 5
# #     print(len(weights_1))
# #     print(len(weights_1[0]))

# sum = 0

# for i in range(number_nodes):
#     for j in range(number_inputs):
#         sum += test_sam[j] * weights_1[j][i]
#     sum += biases_1[i]
#     results.append(max(0, sum))
#     sum = 0

# sum = 0

# for i in range(number_nodes):
#     for j in range(len(results)):
#         sum += results[j] * weights_2[j][i]
#     sum += biases_2[i]
#     results_2.append(max(0, sum))
#     sum = 0

# sum = 0

# for i in range(output_nodes):
#     for j in range(len(results)):
#         sum += results_2[j] * weights_3[j][i]
#     sum += biases_3[i]
#     results_3.append(sum)
#     sum = 0
# if max(results) > max_int:
#     max_int = max(results)
# if max(results_2) > max_int:
#     max_int = max(results_2)
# if max(results_3) > max_int:
#     max_int = max(results_3)

# if min(results) < min_int:
#     min_int = min(results)
# if min(results_2) < min_int:
#     min_int = min(results_2)
# if min(results_3) < min_int:
#     min_int = min(results_3)


        
# print(results_3)

# %%
test_dam = [18,70,110,118,179,138,50]

q = model.predict(np.array([test_sam]))
print(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 test_dam = [18,70,110,118,179,138,50]
# ----> 3 q = model.predict(np.array([test_sam]))
#       4 print(q)
#
# NameError: name 'test_sam' is not defined

# %%
# print("learned weights =", weights)

# # Biases are similar because they are all initialized with zeros (by default).
# print("learned biases =", biases)
from numpy  import exp
from numpy  import sum

def softmax(vector):
    e = exp(vector)
    return e / e.sum()


print("results3 =", results_3)



after_activation = softmax(results_3)
print(after_activation)
print(sum(after_activation))
print(sum(q))

# %%
# for i in range (len(weights_1)):
#     print("{", end="")
#     for j in range (len(weights_1[0])-1):
#         print(f"{weights_1[i][j]},", end="")
#     print(f"{weights_1[i][63]}", end="")
#     print("},")

# for i in range (len(weights_2)):
#     print("{", end="")
#     for j in range (len(weights_2[0])-1):
#         print(f"{weights_2[i][j]},", end="")
#     print(f"{weights_2[i][63]}", end="")
#     print("},")

for i in range (len(weights_3)):
    print("{", end="")
    for j in range (len(weights_3[0])-1):
        print(f"{weights_3[i][j]},", end="")
    print(f"{weights_3[i][len(weights_3[0])-1]}", end="")
    print("},")    

# print(len(weights_3))
# Out:
# {0.04864830896258354,-0.24172139167785645,0.2548544704914093,0.3024204969406128,0.011656556278467178},
# {-0.19961903989315033,-0.040217071771621704,0.22639918327331543,0.07599116861820221,-0.10656542330980301},
# {0.2325955480337143,0.20207442343235016,0.17219871282577515,-0.0965297594666481,0.27928414940834045},
# {0.08155077695846558,0.18725800514221191,-0.03070788085460663,-0.2709612548351288,0.276103138923645},
# {-0.051354385912418365,0.21635472774505615,-0.10807384550571442,0.11796680092811584,0.056104954332113266},
# {-0.03391920030117035,0.03977305069565773,0.003684868337586522,-0.1048269048333168,-0.21506048738956451},
# {-0.13080111145973206,-0.06028285622596741,0.1643723100423813,0.0637858435511589,0.2660607099533081},
# {0.2929009199142456,0.2847486436367035,0.08973968029022217,-0.1970866471529007,-0.2976997494697571},
# {-0.013618445955216885,-0.20740073919296265,0.28814059495925903,0.23640617728233337,-0.1285199522972107},
# ...

# %%
print(len(biases_1))
print(len(biases_2))
print(len(biases_3))

# for i in range (len(biases_1)-1):
#         print(f"{biases_1[i]},", end="")
# print(f"{biases_1[63]}")


# for i in range (len(biases_2)-1):
#         print(f"{biases_2[i]},", end="")
# print(f"{biases_2[63]}")

# print(biases_3)
for i in range (len(biases_3)-1):
        print(f"{biases_3[i]},", end="")
print(f"{biases_3[len(biases_3)-1]}", end="")
# Out:
# 64
# 64
# 5
# 0.05498446896672249,-0.024124350398778915,-0.007682196795940399,-0.0019989274442195892,-0.018922096118330956

# %%
test_num = 19
for i in range(50):
    test_sam = scaled_samples[i]
    test_label = lable_list[i]

    q = model.predict(np.array([test_sam]))
    print(q)
    print(test_label)


    print(np.int8(q))

# %%
print(len(test_sam))

print(max(0,-21))

# %%
# %history -g -f log.txt

# %%
lut_table = [0.000045,0.000046,0.000046,0.000047,0.000047,0.000048,0.000048,0.000049,0.000049,0.000050,0.000050,0.000051,0.000051,0.000052,0.000052,0.000053,0.000053,0.000054,0.000054,0.000055,0.000055,0.000056,0.000057,0.000057,0.000058,0.000058,0.000059,0.000059,0.000060,0.000061,0.000061,0.000062,0.000063,0.000063,0.000064,0.000064,0.000065,0.000066,0.000066,0.000067,0.000068,0.000068,0.000069,0.000070,0.000070,0.000071,0.000072,0.000073,0.000073,0.000074,0.000075,0.000076,0.000076,0.000077,0.000078,0.000079,0.000079,0.000080,0.000081,0.000082,0.000083,0.000084,0.000084,0.000085,0.000086,0.000087,0.000088,0.000089,0.000090,0.000091,0.000091,0.000092,0.000093,0.000094,0.000095,0.000096,0.000097,0.000098,0.000099,0.000100,0.000101,0.000102,0.000103,0.000104,0.000105,0.000106,0.000
115.280973,7186.790736,7259.019183,7331.973539,7405.661098,7480.089230,7555.265376,7631.197056,7707.891861,7785.357462,7863.601605,7942.632116,8022.456895,8103.083928,8184.521275,8266.777081,8349.859572,8433.777056,8518.537925,8604.150654,8690.623806,8777.966027,8866.186052,8955.292703,9045.294891,9136.201616,9228.021969,9320.765132,9414.440379,9509.057078,9604.624690,9701.152773,9798.650979,9897.129059,9996.596859,10097.064328,10198.541512,10301.038558,10404.565717,10509.133340,10614.751886,10721.431916,10829.184099,10938.019208,11047.948129,11158.981853,11271.131486,11384.408240,11498.823445,11614.388542,11731.115087,11849.014754,11968.099332,12088.380730,12209.870976,12332.582220,12456.526732,12581.716907,12708.165264,12835.884448,12964.887231,13095.186514,13226.795327,13359.726830,13493.994316,13629.611214,13766.591084,13904.947625,14044.694672,14185.846200,14328.416324,14472.419302,14617.869534,14764.781566,14913.170087,15063.049938,15214.436107,15367.343732,15521.788104,15677.784668,15835.349024,15994.496927,16155.244294,16317.607198,16481.601877,16647.244729,16814.552320,16983.541381,17154.228809,17326.631675,17500.767218,17676.652853,17854.306168,18033.744928,18214.987078,18398.050741,18582.954225,18769.716020,18958.354802,19148.889435,19341.338974,19535.722662,19732.059939,19930.370438,20130.673991,20332.990628,20537.340581,20743.744286,20952.222382,21162.795718,21375.485350,21590.312550,21807.298798]
print(len(lut_table))

print(lut_table[1010])

# %%
weights_1 = model.layers[1].get_weights()[0]
biases_1 = model.layers[1].get_weights()[1]


weights_2 = model.layers[2].get_weights()[0]
biases_2  = model.layers[2].get_weights()[1]

weights_3 = model.layers[3].get_weights()[0]
biases_3  = model.layers[3].get_weights()[1]


max_int = 0
min_int = 0

for k in range(20):
    
    
    test_sam = scaled_samples[1260+k]
    test_label = lable_list[1260+k]
    q = model.predict(np.array([test_sam]))

    
    results = []
    results_2 = []
    results_3 = []


    number_nodes = 64
    number_inputs = 300
    output_nodes = 5
#     print(len(weights_1))
#     print(len(weights_1[0]))

    sum = 0

    for i in range(number_nodes):
        for j in range(number_inputs):
            sum += test_sam[j] * weights_1[j][i]
        sum += biases_1[i]
        results.append(max(0, sum))
        sum = 0

    sum = 0

    for i in range(number_nodes):
        for j in range(len(results)):
            sum += results[j] * weights_2[j][i]
        sum += biases_2[i]
        results_2.append(max(0, sum))
        sum = 0

    sum = 0

    for i in range(output_nodes):
        for j in range(len(results)):
            sum += results_2[j] * weights_3[j][i]
        sum += biases_3[i]
        results_3.append(sum)
        sum = 0
    
    print(results_3)   
    print(np.int8(results_3))   
# #     if max(results) > max_int:
# #         max_int = max(results)
# #     if max(results_2) > max_int:
# #         max_int = max(results_2)
#     if max(results_3) > max_int:
#         max_int = max(results_3)
#         print(k)


# #     if min(results) < min_int:
# #         min_int = min(results)
# #     if min(results_2) < min_int:
# #         min_int = min(results_2)
#     if min(results_3) < min_int:
#         min_int = min(results_3)
#     if int(np.argmax(q)) != int(np.argmax(results_3)):
#         print(int(np.argmax(q)), int(np.argmax(results_3)))



# print(max_int,min_int)

# %%
print(np.exp(190))
